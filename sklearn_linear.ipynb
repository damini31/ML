# %%
pip install pydataset
# Out:
# Collecting pydataset
#   Downloading pydataset-0.2.0.tar.gz (15.9 MB)
# Requirement already satisfied: pandas in c:\users\daminichauhan1997\anaconda3\lib\site-packages (from pydataset) (1.0.1)
# Requirement already satisfied: pytz>=2017.2 in c:\users\daminichauhan1997\anaconda3\lib\site-packages (from pandas->pydataset) (2019.3)
# Requirement already satisfied: python-dateutil>=2.6.1 in c:\users\daminichauhan1997\anaconda3\lib\site-packages (from pandas->pydataset) (2.8.1)
# Requirement already satisfied: numpy>=1.13.3 in c:\users\daminichauhan1997\anaconda3\lib\site-packages (from pandas->pydataset) (1.18.1)
# Requirement already satisfied: six>=1.5 in c:\users\daminichauhan1997\anaconda3\lib\site-packages (from python-dateutil>=2.6.1->pandas->pydataset) (1.14.0)
# Building wheels for collected packages: pydataset
#   Building wheel for pydataset (setup.py): started
#   Building wheel for pydataset (setup.py): finished with status 'done'
#   Created wheel for pydataset: filename=pydataset-0.2.0-py3-none-any.whl size=15939434 sha256=26b14b4663158fbb9a4df4d7573cb3d81e56afd6f8d2bfa7f3630e45dcdfe192
#   Stored in directory: c:\users\daminichauhan1997\appdata\local\pip\cache\wheels\32\26\30\d71562a19eed948eaada9a61b4d722fa358657a3bfb5d151e2
# Successfully built pydataset
# Installing collected packages: pydataset
# Successfully installed pydataset-0.2.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from pydataset import data
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt

# %%
# %matplotlib notebook

# %%
pima=data('Pima.tr')

# %%
pima.plot(kind='scatter',x='skin',y='bmi')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#train-test test
X_train, X_test, Y_train, Y_test=train_test_split(pima.skin,pima.bmi)

# %%
plt.scatter(X_train,Y_train,label='training data',color='r',alpha=0.7)
plt.scatter(X_test,Y_test,label='testing data',color='g',alpha=0.7)
plt.legend()
plt.title('test-train data')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
LR=LinearRegression()
LR.fit(X_train.values.reshape(-1, 1),Y_train.values)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
prediction = LR.predict(X_test.values.reshape(-1,1))
plt.plot(X_test,prediction,label='Linear Regression',color='b')
plt.scatter(X_test,Y_test,label="Actual test data",color='g',alpha=.7)
plt.xlabel("-----------Skin----------->")
plt.ylabel("------------bmi----------->")
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
LR.predict(np.array([[50]]))[0]
# Out:
# 38.87265840213676

# %%
LR.score(X_test.values.reshape(-1, 1),Y_test.values)
# Out:
# 0.6077731213956423
